# %%
# %pip install xgboost
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: xgboost in c:\users\cheta\appdata\roaming\python\python313\site-packages (3.2.0)
# Requirement already satisfied: numpy in c:\programdata\anaconda3\lib\site-packages (from xgboost) (2.1.3)
# Requirement already satisfied: scipy in c:\programdata\anaconda3\lib\site-packages (from xgboost) (1.15.3)
# Note: you may need to restart the kernel to use updated packages.

# %%
conda install -c conda-forge xgboost
# Out:
# Jupyter detected...
#
# Note: you may need to restart the kernel to use updated packages.
# CondaToSNonInteractiveError: Terms of Service have not been accepted for the following channels. Please accept or remove them before proceeding:
#     • https://repo.anaconda.com/pkgs/r
#     • https://repo.anaconda.com/pkgs/msys2
#
# To accept a channel's Terms of Service, run the following and replace `CHANNEL` with the channel name/URL:
#     \u2023 conda tos accept --override-channels --channel CHANNEL
#
# To remove channels with rejected Terms of Service, run the following and replace `CHANNEL` with the channel name/URL:
#     \u2023 conda config --remove channels CHANNEL

# %%
import pandas as pd
import numpy as np
from sklearn.metrics import mean_absolute_error,mean_squared_error,r2_score
from sklearn.model_selection import train_test_split,RandomizedSearchCV
from sklearn.preprocessing import LabelEncoder
from xgboost import XGBRegressor
import pickle

# %%
df = pd.read_csv('demand_forecasting.csv')

# %%
df.columns
# Out:
# Index(['Date', 'Store ID', 'Product ID', 'Category', 'Region',
#        'Inventory Level', 'Units Sold', 'Units Ordered', 'Price', 'Discount',
#        'Weather Condition', 'Promotion', 'Competitor Pricing', 'Seasonality',
#        'Epidemic', 'Demand'],
#       dtype='object')

# %%
features=[
    'Price',
    'Discount',
    'Inventory Level',
    'Promotion',
    'Competitor Pricing',
    'Category'
]

# %%
features
# Out:
# ['Price',
#  'Discount',
#  'Inventory Level',
#  'Promotion',
#  'Competitor Pricing',
#  'Category']

# %%
target = 'Demand'

# %%
x=df[features].copy()

# %%
x
# Out:
#         Price  Discount  Inventory Level  Promotion  Competitor Pricing  \
# 0       72.72         5              195          0               85.73
# 1       80.16        15              117          1               92.02
# 2       62.94        10              247          1               60.08
# 3       87.63        10              139          0               85.19
# 4       54.41         0              152          0               51.63
# ...       ...       ...              ...        ...                 ...
# 75995   29.80         5              233          0               32.23
# 75996   42.92         5              137          0               40.73
# 75997   17.81        10              197          0               19.41
# 75998  151.72         0              125          0              143.71
# 75999   25.78        10              126          0               29.32
#
#           Category
# 0      Electronics
# 1         Clothing
# 2         Clothing
# 3      Electronics
# 4        Groceries
# ...            ...
# 75995         Toys
# 75996         Toys
# 75997     Clothing
# 75998    Furniture
# 75999         Toys
#
# [76000 rows x 6 columns]

# %%
y=df[target]

# %%
y
# Out:
# 0        115
# 1        229
# 2        157
# 3         52
# 4         59
#         ...
# 75995     64
# 75996    137
# 75997     68
# 75998     84
# 75999     73
# Name: Demand, Length: 76000, dtype: int64

# %%
label_encoders={}
categorical_cols = x.select_dtypes(include='object').columns

# %%
categorical_cols
# Out:
# Index(['Category'], dtype='object')

# %%
for col in categorical_cols:
    le = LabelEncoder()
    x[col]=le.fit_transform(x[col])
    label_encoders[col]=le

# %%
label_encoders
# Out:
# {'Category': LabelEncoder()}

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2)

# %%
x_train
# Out:
#         Price  Discount  Inventory Level  Promotion  Competitor Pricing  \
# 17023   43.96        10               15          1               47.74
# 24096   33.98        10               78          0               33.94
# 3684    19.79         0               11          0               17.86
# 54569   27.87        10              750          0               25.81
# 74228   70.50         5              178          0               61.59
# ...       ...       ...              ...        ...                 ...
# 825     81.45         0              162          0               71.23
# 15786   83.20         5               34          0               98.96
# 26859   69.90        10              721          0               62.09
# 59424   78.23        10              583          0               75.29
# 35998  121.55        25              183          1              110.68
#
#        Category
# 17023         3
# 24096         4
# 3684          3
# 54569         3
# 74228         3
# ...         ...
# 825           0
# 15786         3
# 26859         0
# 59424         1
# 35998         2
#
# [60800 rows x 6 columns]

# %%
xgb = XGBRegressor(objective  = 'reg:squarederror',n_job=-1)

# %%
param_dict={
    'n_estimators':[200,300,500],
    'max_depth':[3,4,6,8],
    'learning_rate':[0.1,0.05,0.1],
    'subsample':[0.7,0.8,1.0],
    'colsample_bytree':[0.7,0.8,1.0],
    'min_child_weight':[1,3,5]
}

# %%
random_search= RandomizedSearchCV(
    estimator=xgb,
    param_distributions=param_dict,
    n_iter=25,
    scoring='neg_mean_absolute_error',
    cv=3,
    verbose=1,
    n_jobs=-1
)

# %%
random_search.fit(x_train,y_train)
# Out:
# Fitting 3 folds for each of 25 candidates, totalling 75 fits
# C:\Users\cheta\AppData\Roaming\Python\Python313\site-packages\xgboost\training.py:200: UserWarning: [13:40:42] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:782:
# Parameters: { "n_job" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# RandomizedSearchCV(cv=3,
#                    estimator=XGBRegressor(base_score=None, booster=None,
#                                           callbacks=None,
#                                           colsample_bylevel=None,
#                                           colsample_bynode=None,
#                                           colsample_bytree=None, device=None,
#                                           early_stopping_rounds=None,
#                                           enable_categorical=False,
#                                           eval_metric=None, feature_types=None,
#                                           feature_weights=None, gamma=None,
#                                           grow_policy=None,
#                                           importance_type=None,
#                                           interaction_constraint...
#                                           min_child_weight=None, missing=nan,
#                                           monotone_constraints=None,
#                                           multi_strategy=None,
#                                           n_estimators=None, n_job=-1,
#                                           n_jobs=None, ...),
#                    n_iter=25, n_jobs=-1,
#                    param_distributions={'colsample_bytree': [0.7, 0.8, 1.0],
#                                         'learning_rate': [0.1, 0.05, 0.1],
#                                         'max_depth': [3, 4, 6, 8],
#                                         'min_child_weight': [1, 3, 5],
#                                         'n_estimators': [200, 300, 500],
#                                         'subsample': [0.7, 0.8, 1.0]},
#                    scoring='neg_mean_absolute_error', verbose=1)

# %%
random_search.best_params_
# Out:
# {'subsample': 1.0,
#  'n_estimators': 200,
#  'min_child_weight': 1,
#  'max_depth': 8,
#  'learning_rate': 0.05,
#  'colsample_bytree': 1.0}

# %%
best_model = random_search.best_estimator_

# %%
y_pred = best_model.predict(x_test)

# %%
mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)

print("RMSE:", rmse)
# Out:
# RMSE: 35.76950373517835

# %%
best_model.feature_importances_
# Out:
# array([0.05898221, 0.01509497, 0.01357388, 0.6323671 , 0.01815121,
#        0.26183075], dtype=float32)

# %%
feature_importance = pd.Series(
    best_model.feature_importances_,
    index = x.columns
).sort_values(ascending=False)

# %%
feature_importance
# Out:
# Promotion             0.632367
# Category              0.261831
# Price                 0.058982
# Competitor Pricing    0.018151
# Discount              0.015095
# Inventory Level       0.013574
# dtype: float32

# %%
feature_importance.plot(kind='bar',title='Feature Importances')
# Out:
# <Axes: title={'center': 'Feature Importances'}>

# %%
with open('label_encoders.pkl','wb') as f:
    pickle.dump(label_encoders,f)

# %%
with open('xgboost_demand_model.pkl','wb') as f:
    pickle.dump(best_model,f)
