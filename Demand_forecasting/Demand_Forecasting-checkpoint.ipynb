# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# %%
df = pd.read_csv('demand_forecasting.csv')

# %%
df.head()
# Out:
#          Date Store ID Product ID     Category Region  Inventory Level  \
# 0  2022-01-01     S001      P0001  Electronics  North              195
# 1  2022-01-01     S001      P0002     Clothing  North              117
# 2  2022-01-01     S001      P0003     Clothing  North              247
# 3  2022-01-01     S001      P0004  Electronics  North              139
# 4  2022-01-01     S001      P0005    Groceries  North              152
#
#    Units Sold  Units Ordered  Price  Discount Weather Condition  Promotion  \
# 0         102            252  72.72         5             Snowy          0
# 1         117            249  80.16        15             Snowy          1
# 2         114            612  62.94        10             Snowy          1
# 3          45            102  87.63        10             Snowy          0
# 4          65            271  54.41         0             Snowy          0
#
#    Competitor Pricing Seasonality  Epidemic  Demand
# 0               85.73      Winter         0     115
# 1               92.02      Winter         0     229
# 2               60.08      Winter         0     157
# 3               85.19      Winter         0      52
# 4               51.63      Winter         0      59

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 76000 entries, 0 to 75999
# Data columns (total 16 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Date                76000 non-null  object
#  1   Store ID            76000 non-null  object
#  2   Product ID          76000 non-null  object
#  3   Category            76000 non-null  object
#  4   Region              76000 non-null  object
#  5   Inventory Level     76000 non-null  int64
#  6   Units Sold          76000 non-null  int64
#  7   Units Ordered       76000 non-null  int64
#  8   Price               76000 non-null  float64
#  9   Discount            76000 non-null  int64
#  10  Weather Condition   76000 non-null  object
#  11  Promotion           76000 non-null  int64
#  12  Competitor Pricing  76000 non-null  float64
#  13  Seasonality         76000 non-null  object
#  14  Epidemic            76000 non-null  int64
#  15  Demand              76000 non-null  int64
# dtypes: float64(2), int64(7), object(7)
# memory usage: 9.3+ MB

# %%
df.isnull().sum()
# Out:
# Date                  0
# Store ID              0
# Product ID            0
# Category              0
# Region                0
# Inventory Level       0
# Units Sold            0
# Units Ordered         0
# Price                 0
# Discount              0
# Weather Condition     0
# Promotion             0
# Competitor Pricing    0
# Seasonality           0
# Epidemic              0
# Demand                0
# dtype: int64

# %%
df.describe()
# Out:
#        Inventory Level    Units Sold  Units Ordered         Price  \
# count     76000.000000  76000.000000   76000.000000  76000.000000
# mean        301.062842     88.827316      89.090645     67.726028
# std         226.510161     43.994525     162.404627     39.377899
# min           0.000000      0.000000       0.000000      4.740000
# 25%         136.000000     58.000000       0.000000     31.997500
# 50%         227.000000     84.000000       0.000000     64.500000
# 75%         408.000000    114.000000     121.000000     95.830000
# max        2267.000000    426.000000    1616.000000    228.030000
#
#            Discount     Promotion  Competitor Pricing      Epidemic  \
# count  76000.000000  76000.000000        76000.000000  76000.000000
# mean       9.087039      0.328947           69.454029      0.200000
# std        7.475781      0.469834           40.943818      0.400003
# min        0.000000      0.000000            4.290000      0.000000
# 25%        5.000000      0.000000           32.620000      0.000000
# 50%       10.000000      0.000000           65.700000      0.000000
# 75%       10.000000      1.000000           97.932500      0.000000
# max       25.000000      1.000000          261.220000      1.000000
#
#              Demand
# count  76000.000000
# mean     104.317158
# std       46.964801
# min        4.000000
# 25%       71.000000
# 50%      100.000000
# 75%      133.000000
# max      430.000000

# %%
plt.figure(figsize = (10,6))
sns.set(style = 'whitegrid')

# %%
df.dtypes
# Out:
# Date                   object
# Store ID               object
# Product ID             object
# Category               object
# Region                 object
# Inventory Level         int64
# Units Sold              int64
# Units Ordered           int64
# Price                 float64
# Discount                int64
# Weather Condition      object
# Promotion               int64
# Competitor Pricing    float64
# Seasonality            object
# Epidemic                int64
# Demand                  int64
# dtype: object

# %%
df.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 75995    False
# 75996    False
# 75997    False
# 75998    False
# 75999    False
# Length: 76000, dtype: bool

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.describe(include='object').T
# Out:
#                    count unique         top   freq
# Date               76000    760  2024-01-30    100
# Store ID           76000      5        S001  15200
# Product ID         76000     20       P0001   3800
# Category           76000      5   Groceries  30400
# Region             76000      4       North  30400
# Weather Condition  76000      4      Cloudy  24360
# Seasonality        76000      4      Winter  21000

# %%
df['Date'] = pd.to_datetime(df['Date'])
df['Year'] = df['Date'].dt.year
df['Month'] = df['Date'].dt.month

# %%
df.head()
# Out:
#         Date Store ID Product ID     Category Region  Inventory Level  \
# 0 2022-01-01     S001      P0001  Electronics  North              195
# 1 2022-01-01     S001      P0002     Clothing  North              117
# 2 2022-01-01     S001      P0003     Clothing  North              247
# 3 2022-01-01     S001      P0004  Electronics  North              139
# 4 2022-01-01     S001      P0005    Groceries  North              152
#
#    Units Sold  Units Ordered  Price  Discount Weather Condition  Promotion  \
# 0         102            252  72.72         5             Snowy          0
# 1         117            249  80.16        15             Snowy          1
# 2         114            612  62.94        10             Snowy          1
# 3          45            102  87.63        10             Snowy          0
# 4          65            271  54.41         0             Snowy          0
#
#    Competitor Pricing Seasonality  Epidemic  Demand  Year  Month
# 0               85.73      Winter         0     115  2022      1
# 1               92.02      Winter         0     229  2022      1
# 2               60.08      Winter         0     157  2022      1
# 3               85.19      Winter         0      52  2022      1
# 4               51.63      Winter         0      59  2022      1

# %%
df['Day'] = df['Date'].dt.day
df['Weekday'] = df['Date'].dt.day_name()

# %%
df.sample(5)
# Out:
#             Date Store ID Product ID     Category Region  Inventory Level  \
# 44348 2023-03-20     S003      P0009    Groceries   East               96
# 45400 2023-03-31     S001      P0001  Electronics  North              294
# 63292 2023-09-25     S005      P0013    Groceries  North              203
# 27145 2022-09-29     S003      P0006         Toys   East              139
# 24511 2022-09-03     S001      P0012    Groceries  North              381
#
#        Units Sold  Units Ordered  Price  Discount Weather Condition  \
# 44348          96            136  64.19         0             Sunny
# 45400          65              0  58.23        10            Cloudy
# 63292          96              0  87.67         0             Snowy
# 27145          86            124  39.44        10            Cloudy
# 24511         150              0  84.68        10             Sunny
#
#        Promotion  Competitor Pricing Seasonality  Epidemic  Demand  Year  \
# 44348          0               69.76      Spring         0     154  2023
# 45400          0               67.84      Spring         0      65  2023
# 63292          0              105.57      Autumn         0     152  2023
# 27145          0               38.39      Autumn         0     113  2022
# 24511          0               94.96      Autumn         0     139  2022
#
#        Month  Day   Weekday
# 44348      3   20    Monday
# 45400      3   31    Friday
# 63292      9   25    Monday
# 27145      9   29  Thursday
# 24511      9    3  Saturday

# %%
df['Discounted_Price'] = df['Price'] * (1-df['Discount']/100)

# %%
df.sample(5)
# Out:
#             Date Store ID Product ID     Category Region  Inventory Level  \
# 40233 2023-02-07     S002      P0014  Electronics  South              116
# 13228 2022-05-13     S002      P0009    Groceries  South              265
# 33103 2022-11-28     S001      P0004  Electronics  North               67
# 61320 2023-09-06     S002      P0001    Groceries  South              401
# 32167 2022-11-18     S004      P0008    Furniture   West               61
#
#        Units Sold  Units Ordered   Price  Discount  ... Promotion  \
# 40233          82              0  108.56         5  ...         0
# 13228          79            217   46.16        25  ...         1
# 33103          67              0   71.19        25  ...         1
# 61320           4              0   55.95         5  ...         0
# 32167          50             50   96.83         0  ...         0
#
#        Competitor Pricing  Seasonality Epidemic  Demand  Year  Month  Day  \
# 40233              120.13       Winter        1      70  2023      2    7
# 13228               53.97       Spring        1      94  2022      5   13
# 33103               77.49       Autumn        0      58  2022     11   28
# 61320               53.29       Autumn        0       4  2023      9    6
# 32167               83.55       Autumn        0      56  2022     11   18
#
#          Weekday Discounted_Price
# 40233    Tuesday         103.1320
# 13228     Friday          34.6200
# 33103     Monday          53.3925
# 61320  Wednesday          53.1525
# 32167     Friday          96.8300
#
# [5 rows x 21 columns]

# %%
df['Sell Through Rate'] = df['Units Sold']/df['Inventory Level']

# %%
df['Sell Through Rate'].describe()
# Out:
# count    75594.000000
# mean         0.437580
# std          0.298007
# min          0.003150
# 25%          0.190807
# 50%          0.350475
# 75%          0.642276
# max          1.000000
# Name: Sell Through Rate, dtype: float64

# %%
df.groupby('Category')['Demand'].agg(['mean','sum','std']).sort_values(by='sum',ascending=False).reset_index()
# Out:
#       Category        mean      sum        std
# 0    Groceries  120.976447  3677684  48.362730
# 1     Clothing  112.619737  1369456  41.022968
# 2    Furniture   73.581140  1006590  32.336141
# 3         Toys   92.606955   985338  46.170390
# 4  Electronics   97.482018   889036  40.557859

# %%
df.groupby(['Region','Seasonality'])['Demand'].mean()
# Out:
# Region  Seasonality
# East    Autumn         106.353297
#         Spring         100.168478
#         Summer         115.388315
#         Winter         104.273571
# North   Autumn         103.065797
#         Spring          97.399457
#         Summer         112.843750
#         Winter         102.017738
# South   Autumn         104.464560
#         Spring         100.328804
#         Summer         115.089946
#         Winter         107.733095
# West    Autumn         100.165385
#         Spring          93.219293
#         Summer         108.111141
#         Winter         100.988810
# Name: Demand, dtype: float64

# %%
df.groupby('Promotion')['Demand'].mean()
# Out:
# Promotion
# 0     95.026843
# 1    123.269400
# Name: Demand, dtype: float64

# %%
pd.pivot_table(df,values='Demand',index='Month',columns='Category',aggfunc='mean')
# Out:
# Category    Clothing  Electronics  Furniture   Groceries        Toys
# Month
# 1         126.997962    99.519022  75.690821  117.399457   94.242236
# 2         128.966518    84.184524  61.625992  103.522768   68.885204
# 3         105.835685   108.120968  84.015233  126.561694  128.273041
# 4         106.972917    85.916667  63.005556  105.111250   85.753571
# 5         108.650202    79.577957  56.036738   98.637903   71.756912
# 6         105.670833   106.922222  79.908333  147.772500  100.825000
# 7         107.838710    87.418011  66.156810  128.744355   74.366359
# 8         107.871976   109.733871  83.524194  149.875403  102.794931
# 9         105.118750   105.015278  81.854630  122.239167  102.722619
# 10        107.113911    89.354839  69.279570  109.765323   80.857143
# 11        106.306250   107.495833  82.033333  122.121250  100.138095
# 12        127.865927   104.750000  78.067204  120.438306   98.194700

# %%
sns.histplot(df['Demand'],bins=20,kde=True)
plt.title('Demand Distribution')
plt.show()

# %%
sns.scatterplot(data = df,x='Inventory Level',y='Units Sold')
plt.title('Inventory vs Units Sold')
plt.show()

# %%
sns.boxplot(data=df,x='Category',y='Demand')
plt.xticks(rotation = 45)
plt.title('Demand by Category')
plt.show()

# %%
sns.boxplot(data=df,x='Weather Condition',y='Demand')
plt.xticks(rotation = 45)
plt.title('Demand by Weather Condition')
plt.show()

# %%
monthly_demand = df.groupby('Month')['Demand'].mean()

# %%
monthly_demand
# Out:
# Month
# 1     106.040000
# 2      92.882500
# 3     113.613871
# 4      92.816667
# 5      86.521129
# 6     117.346000
# 7     101.561613
# 8     119.803387
# 9     107.431500
# 10     95.557258
# 11    107.542333
# 12    109.003226
# Name: Demand, dtype: float64

# %%
monthly_demand.plot(kind='bar')
plt.title('Average Demand by Month')
plt.show()

# %%
daily_demand = df.groupby('Date')['Demand'].mean()

# %%
daily_demand
# Out:
# Date
# 2022-01-01    100.60
# 2022-01-02    108.14
# 2022-01-03    113.17
# 2022-01-04    114.69
# 2022-01-05    117.24
#                ...
# 2024-01-26    111.82
# 2024-01-27    115.40
# 2024-01-28    114.40
# 2024-01-29    102.68
# 2024-01-30     96.57
# Name: Demand, Length: 760, dtype: float64

# %%
daily_demand.plot()
plt.title('Total Daily Demand Over Time')
plt.xlabel('Date')
plt.ylabel('Demand')
plt.show()

# %%
sns.barplot(data=df,x='Promotion',y='Demand')
plt.title('Promotion impact on Demand')
plt.show()

# %%
sns.scatterplot(data=df,x='Discounted_Price',y='Demand')
plt.title('Discounted Price vs Demand')
plt.show()

# %%
df.groupby('Seasonality')['Demand'].mean().plot(kind='bar',title='Demand by Seasonality')
plt.show()

# %%
df.groupby('Epidemic')['Demand'].mean().plot(kind='bar',title='Epidemic impact on Demand')
plt.show()

# %%
df.to_csv('preprocessed_demand_forecasting.csv')
